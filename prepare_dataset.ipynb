# %% [markdown]
# # Подготовка данных

# %% [markdown]
# Предварительно исходные данные должны быть скачены в директорию datasets

# %%
import logging
import os

from dataset_agregator import create_df_from_files, create_entities_df, create_spacy_dataset
from settings import DATASET_DIR

logging.basicConfig(format=u'[%(asctime)s] %(filename)s [%(levelname)s] %(message)s',
                    level=logging.INFO, )
marked_data_dir = os.path.join(DATASET_DIR, "marked")

# %% [markdown]
# # Датафрейм c исходными размеченными данными

# %%
source_df = create_df_from_files(marked_data_dir,
                                 # save_to_scv=True,
                                 )
source_df.head()
# Out:
# [2022-06-10 23:04:56,504] dataset_agregator.py [INFO] Convert txt-files from F:\JetBrains\PycharmProjects\NERTestTask\dataset\marked to pandas.Dataframe
#                                             filename  \
# 0  2020.09.11_Talos_-_The_art_and_science_of_dete...
# 1                  APT Trends report Q2 2017.pdf.txt
# 2            apt-attack-middle-east-big-bang.pdf.txt
# 3                 APT28-Center-of-Storm-2017.pdf.txt
# 4              Backdoor.Winnti_Trojan.Skelky.pdf.txt
#
#                                                 text
# 0  page 1 of 29© 2020 <ORG>Cisco</ORG>. All right...
# 1  APT Trends report <TIMESTAMP>Q2 2017</TIMESTAM...
# 2  CHECKPOINT.COM\n\nPUBLICATIONS TOOLS ABOUT US ...
# 3  <ORG>FireEye</ORG> iSIGHT INTELLIGENCE\n\n<COU...
# 4  <MALWARE>Backdoor.Winnti</MALWARE> attackers h...

# %%
source_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  17 non-null     object
#  1   text      17 non-null     object
# dtypes: object(2)
# memory usage: 400.0+ bytes

# %% [markdown]
# # Датасет spacy

# %%
create_spacy_dataset(source_df['text'].to_list(), output_filename='dev')
# Out:
# [2022-06-10 23:05:02,931] dataset_agregator.py [INFO] Start prepare raw indexed dataset
# [2022-06-10 23:05:03,216] dataset_agregator.py [INFO] Start prepare spacy dataset
# [2022-06-10 23:05:05,968] dataset_agregator.py [INFO] Result dataset successful saved to F:\JetBrains\PycharmProjects\NERTestTask\dataset\dev.spacy
# ...

# %% [markdown]
# # Датафрейм для аналитики и просмотра статистики

# %%
entities_df = create_entities_df(source_df,
                                 # save_to_scv=True,
                                 )
entities_df.head()
# Out:
# [2022-06-10 23:05:06,943] dataset_agregator.py [INFO] Convert source pandas.Dataframe(columns=['filename', 'text']) to entities Dataframe
#                                             filename       tag       entity
# 0  2020.09.11_Talos_-_The_art_and_science_of_dete...  SOFTWARE   PowerShell
# 1  2020.09.11_Talos_-_The_art_and_science_of_dete...  SOFTWARE        SNORT
# 2  2020.09.11_Talos_-_The_art_and_science_of_dete...  SOFTWARE       ClamAV
# 3  2020.09.11_Talos_-_The_art_and_science_of_dete...  SOFTWARE         Java
# 4  2020.09.11_Talos_-_The_art_and_science_of_dete...  SOFTWARE  Windows API

# %%
entities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  1168 non-null   object
#  1   tag       1168 non-null   object
#  2   entity    1168 non-null   object
# dtypes: object(3)
# memory usage: 27.5+ KB
